# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/no1_aggregated/no1_2020_to_2022_aggregated.csv')
df.head()
# Out:
#        start MTU (UTC)        end MTU (UTC)  \
# 0  2020-01-01 00:00:00  2020-01-01 01:00:00
# 1  2020-01-01 01:00:00  2020-01-01 02:00:00
# 2  2020-01-01 02:00:00  2020-01-01 03:00:00
# 3  2020-01-01 03:00:00  2020-01-01 04:00:00
# 4  2020-01-01 04:00:00  2020-01-01 05:00:00
#
#    Day-ahead Price [EUR/MWh] BZN|NO1  Day-ahead Price [EUR/MWh] BZN|NO2  \
# 0                              31.77                              31.77
# 1                              31.57                              31.57
# 2                              31.28                              31.28
# 3                              30.72                              30.72
# 4                              30.27                              30.27
#
#    Day-ahead Price [EUR/MWh] BZN|NO3  Day-ahead Price [EUR/MWh] BZN|NO5  \
# 0                              28.45                              31.77
# 1                              27.90                              31.57
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26304 entries, 0 to 26303
# Data columns (total 55 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   start MTU (UTC)                                                                26304 non-null  object
#  1   end MTU (UTC)                                                                  26304 non-null  object
#  2   Day-ahead Price [EUR/MWh] BZN|NO1                                              26304 non-null  float64
#  3   Day-ahead Price [EUR/MWh] BZN|NO2                                              26304 non-null  float64
#  4   Day-ahead Price [EUR/MWh] BZN|NO3                                              26304 non-null  float64
#  5   Day-ahead Price [EUR/MWh] BZN|NO5                                              26304 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Day-ahead Price [EUR/MWh] BZN|NO1  Day-ahead Price [EUR/MWh] BZN|NO2  \
# count                       26304.000000                       26304.000000
# mean                           92.089895                          98.477096
# std                           102.673358                         114.521343
# min                            -1.970000                          -1.970000
# 25%                            12.530000                          12.537500
# 50%                            54.950000                          57.530000
# 75%                           140.860000                         143.380000
# max                           799.970000                         844.000000
#
#        Day-ahead Price [EUR/MWh] BZN|NO3  Day-ahead Price [EUR/MWh] BZN|NO5  \
# count                       26304.000000                       26304.000000
# mean                           30.802730                          91.868445
# ...

# %%
df['start MTU (UTC)'] = pd.to_datetime(df['start MTU (UTC)'])
df['end MTU (UTC)'] = pd.to_datetime(df['end MTU (UTC)'])

# %%
df.isna().sum()
# Out:
# start MTU (UTC)                                                                   0
# end MTU (UTC)                                                                     0
# Day-ahead Price [EUR/MWh] BZN|NO1                                                 0
# Day-ahead Price [EUR/MWh] BZN|NO2                                                 0
# Day-ahead Price [EUR/MWh] BZN|NO3                                                 0
# Day-ahead Price [EUR/MWh] BZN|NO5                                                 0
# Day-ahead Price [EUR/MWh] BZN|SE3                                                 0
# Actual Total Load [MW] - BZN|NO1                                                  1
# Actual Total Load [MW] - BZN|NO2                                                  1
# Actual Total Load [MW] - BZN|NO3                                                  1
# Actual Total Load [MW] - BZN|NO5                                                  1
# ...

# %%
df.drop(['end MTU (UTC)'], axis=1).plot(x='start MTU (UTC)', subplots=True, figsize=(20, 60))
# Out:
# array([<AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
#        <AxesSubplot: xlabel='start MTU (UTC)'>,
# ...

# %%
# find the best way to fill missing values
