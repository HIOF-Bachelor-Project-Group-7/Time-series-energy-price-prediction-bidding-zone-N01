# %% [markdown]
# # exploratory data analysis - bidding zone NO1 and neighboring zones for the year of 2022

# %%
# importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns # Visualization
import matplotlib.pyplot as plt # Visualization

# %% [markdown]
# ## About the dataset
#
# Hourly electricity prices and external factors for bidding zone NO1 (Norway Østlandet) and neightbouring zones (NO2, NO3, NO5 and SE3).
#
# **Source of the datasets data::** https://transparency.entsoe.eu/dashboard/show
#
# **Attribute information:**
#
# **Target feature:** 	**Day-ahead Price** Spot (day-ahead) market prices in the currency Euro per MWh (megawatt-hour).
# 1.	**Start MTU (UTC):** Start datetime of the interval for the measured values
# 2.	**Start MTU (UTC):** End time of the interval for the measured values
# 3.	**Actual Total Load:** The power consumption in each zone per MW (megawatt)
# 4.	**Biomass:** Energy production in MW  from Biomass.
# 5.	**Fossil Gas:** Energy production in MW  from Fossil Gas.
# 6.	**Hydro Run-of-river and poundage:** Energy production in MW  from Hydro Run-of-river and poundage.
# 7.	**Hydro Water Reservoir:** Energy production in MW  from Hydro Run-of-river and poundage.
# 8.	**Wind Onshore:** Energy production in MW  from onshore wind.
# 9.	**Hydro Pumped Storage Aggregated:** Energy production in MW  from Hydro Pumped Storage Aggregated.
# 10.	**Hydro Run-of-river and poundage:** Energy production in MW  from Hydro Run-of-river and poundage
# 11.	**Other renewable:** Energy production in MW  from Other renewable.
# 12.	**Marine:** Energy production in MW  from Marine.
# 13.	**Solar:** Energy production in MW  from Solar.
# 14.	**CBF BZN|x > BZN|y [MWh]:**  Cross-border physical flow in MWH (mega watt hour), zone x is export zone and zone y is import zone.
# 15.	**Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh]:** Stored Energy Value in Water Reservoirs and Hydro Storage Plants measured in MwH (mega watt hour)

# %% [markdown]
# ## Importing dataset and printing out the resulting dataframe

# %%
# reding in the dataset to a dataframe
df = pd.read_csv('../datasets/no1_aggregated/no1_2020_to_2022_aggregated.csv')

# printing out the 5 first rows of the dataset
df.head()
# Out:
#        start MTU (UTC)        end MTU (UTC)  \
# 0  2020-01-01 00:00:00  2020-01-01 01:00:00
# 1  2020-01-01 01:00:00  2020-01-01 02:00:00
# 2  2020-01-01 02:00:00  2020-01-01 03:00:00
# 3  2020-01-01 03:00:00  2020-01-01 04:00:00
# 4  2020-01-01 04:00:00  2020-01-01 05:00:00
#
#    Day-ahead Price [EUR/MWh] BZN|NO1  Day-ahead Price [EUR/MWh] BZN|NO2  \
# 0                              31.77                              31.77
# 1                              31.57                              31.57
# 2                              31.28                              31.28
# 3                              30.72                              30.72
# 4                              30.27                              30.27
#
#    Day-ahead Price [EUR/MWh] BZN|NO3  Day-ahead Price [EUR/MWh] BZN|NO5  \
# 0                              28.45                              31.77
# 1                              27.90                              31.57
# 2                              27.52                              31.28
# 3                              27.54                              30.72
# 4                              26.55                              30.27
#
#    Day-ahead Price [EUR/MWh] BZN|SE3  Actual Total Load [MW] - BZN|NO1  \
# 0                              28.45                            4333.0
# 1                              27.90                            4250.0
# 2                              27.52                            4167.0
# 3                              27.54                            4145.0
# 4                              26.55                            4222.0
#
#    Actual Total Load [MW] - BZN|NO2  Actual Total Load [MW] - BZN|NO3  ...  \
# 0                            4139.0                            3016.0  ...
# 1                            4114.0                            2945.0  ...
# 2                            4030.0                            3032.0  ...
# 3                            4032.0                            2988.0  ...
# 4                            4032.0                            2848.0  ...
#
#    CBF BZN|NO1 > BZN|NO3 [MW]  CBF BZN|NO5 > BZN|NO1 [MW]  \
# 0                         0.0                      1449.0
# 1                         0.0                      1283.0
# 2                         6.0                       962.0
# 3                         6.0                       767.0
# 4                        22.0                       642.0
#
#    CBF BZN|NO1 > BZN|NO5 [MW]  CBF BZN|SE3 > BZN|NO1 [MW]  \
# 0                         0.0                         391
# 1                         0.0                         348
# 2                         0.0                         500
# 3                         0.0                         610
# 4                         0.0                         909
#
#    CBF BZN|NO1 > BZN|SE3 [MW]  \
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
#
#    Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO1  \
# 0                                          4012000.0
# 1                                          4012000.0
# 2                                          4012000.0
# 3                                          4012000.0
# 4                                          4012000.0
#
#    Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO2  \
# 0                                         24273000.0
# 1                                         24273000.0
# 2                                         24273000.0
# 3                                         24273000.0
# 4                                         24273000.0
#
#    Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO3  \
# 0                                          5588000.0
# 1                                          5588000.0
# 2                                          5588000.0
# 3                                          5588000.0
# 4                                          5588000.0
#
#    Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO5  \
# 0                                         11211000.0
# 1                                         11211000.0
# 2                                         11211000.0
# 3                                         11211000.0
# 4                                         11211000.0
#
#    Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|SE3
# 0                                          2220000.0
# 1                                          2220000.0
# 2                                          2220000.0
# 3                                          2220000.0
# 4                                          2220000.0
#
# [5 rows x 58 columns]

# %%
# printing out the 5 last rows of the dataset
df.tail()
# Out:
#            start MTU (UTC)        end MTU (UTC)  \
# 26299  2022-12-31 19:00:00  2022-12-31 20:00:00
# 26300  2022-12-31 20:00:00  2022-12-31 21:00:00
# 26301  2022-12-31 21:00:00  2022-12-31 22:00:00
# 26302  2022-12-31 22:00:00  2022-12-31 23:00:00
# 26303  2022-12-31 23:00:00  2023-01-01 00:00:00
#
#        Day-ahead Price [EUR/MWh] BZN|NO1  Day-ahead Price [EUR/MWh] BZN|NO2  \
# 26299                             123.61                             123.61
# 26300                             121.09                             121.09
# 26301                             120.00                             120.00
# 26302                             119.98                             119.98
# 26303                             119.32                             119.32
#
#        Day-ahead Price [EUR/MWh] BZN|NO3  Day-ahead Price [EUR/MWh] BZN|NO5  \
# 26299                              23.82                             123.61
# 26300                              23.93                             121.09
# 26301                              23.75                             120.00
# 26302                              23.56                             119.98
# 26303                              23.35                             119.32
#
#        Day-ahead Price [EUR/MWh] BZN|SE3  Actual Total Load [MW] - BZN|NO1  \
# 26299                              11.57                            4650.0
# 26300                              14.89                            4573.0
# 26301                               9.94                            4453.0
# 26302                               4.84                            4389.0
# 26303                               2.01                            4444.0
#
#        Actual Total Load [MW] - BZN|NO2  Actual Total Load [MW] - BZN|NO3  \
# 26299                            4333.0                            3612.0
# 26300                            4270.0                            3605.0
# 26301                            4294.0                            3479.0
# 26302                            4282.0                            3415.0
# 26303                            4182.0                            3346.0
#
#        ...  CBF BZN|NO1 > BZN|NO3 [MW]  CBF BZN|NO5 > BZN|NO1 [MW]  \
# 26299  ...                         0.0                        43.0
# 26300  ...                         0.0                        24.0
# 26301  ...                         0.0                        41.0
# 26302  ...                         0.0                         0.0
# 26303  ...                         0.0                         0.0
#
#        CBF BZN|NO1 > BZN|NO5 [MW]  CBF BZN|SE3 > BZN|NO1 [MW]  \
# 26299                         0.0                        2083
# 26300                         0.0                        2097
# 26301                         0.0                        2007
# 26302                        29.0                        2119
# 26303                        12.0                        1612
#
#        CBF BZN|NO1 > BZN|SE3 [MW]  \
# 26299                           0
# 26300                           0
# 26301                           0
# 26302                           0
# 26303                           0
#
#        Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO1  \
# 26299                                          3915448.0
# 26300                                          3915448.0
# 26301                                          3915448.0
# 26302                                          3915448.0
# 26303                                          3915448.0
#
#        Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO2  \
# 26299                                         21384042.0
# 26300                                         21384042.0
# 26301                                         21384042.0
# 26302                                         21384042.0
# 26303                                         21384042.0
#
#        Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO3  \
# 26299                                          5038234.0
# 26300                                          5038234.0
# 26301                                          5038234.0
# 26302                                          5038234.0
# 26303                                          5038234.0
#
#        Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO5  \
# 26299                                         12014136.0
# 26300                                         12014136.0
# 26301                                         12014136.0
# 26302                                         12014136.0
# 26303                                         12014136.0
#
#        Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|SE3
# 26299                                          1579000.0
# 26300                                          1579000.0
# 26301                                          1579000.0
# 26302                                          1579000.0
# 26303                                          1579000.0
#
# [5 rows x 58 columns]

# %%
# printing out the shape of the dataset
df.shape
# Out:
# (26304, 58)

# %% [markdown]
# We can see that the time series data is measured in intervals of 1 hour, and that we have 26304 rows starting at the start of 2020, ending at the end of 2022. Furthermore, we see that we have 58 columns which each belong to one of the 15 feature categories or the target feature.

# %%
# printing out info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26304 entries, 0 to 26303
# Data columns (total 58 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   start MTU (UTC)                                                                26304 non-null  object
#  1   end MTU (UTC)                                                                  26304 non-null  object
#  2   Day-ahead Price [EUR/MWh] BZN|NO1                                              26304 non-null  float64
#  3   Day-ahead Price [EUR/MWh] BZN|NO2                                              26304 non-null  float64
#  4   Day-ahead Price [EUR/MWh] BZN|NO3                                              26304 non-null  float64
#  5   Day-ahead Price [EUR/MWh] BZN|NO5                                              26304 non-null  float64
#  6   Day-ahead Price [EUR/MWh] BZN|SE3                                              26304 non-null  float64
#  7   Actual Total Load [MW] - BZN|NO1                                               26303 non-null  float64
#  8   Actual Total Load [MW] - BZN|NO2                                               26303 non-null  float64
#  9   Actual Total Load [MW] - BZN|NO3                                               26303 non-null  float64
#  10  Actual Total Load [MW] - BZN|NO5                                               26303 non-null  float64
#  11  Actual Total Load [MW] - BZN|SE3                                               26304 non-null  int64
#  12  Fossil Gas - BZN|NO1                                                           26299 non-null  float64
#  13  Hydro Run-of-river and poundage - BZN|NO1                                      26299 non-null  float64
#  14  Hydro Water Reservoir - BZN|NO1                                                26299 non-null  float64
#  15  Other - BZN|NO1                                                                26304 non-null  float64
stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|SE3  26304 non-null  float64
# dtypes: float64(53), int64(3), object(2)
# memory usage: 11.6+ MB

# %% [markdown]
# We Can see that the datetime columns are of the data type object, so we ned to convert it into the data type datetime. The remaining values are numerical data and have appropriate data types.
#
# We also notice that the value onthe 'non-null count' of allot of the columns are less than the size of the dataset (26304), and we therefore know that allot of the features have missing values. We should therefore investigate which values are misssing, and handle the missing values accordingly. We will handle the missing values once the data has been split into training and test data, this is to avoid data leakage where training data contains information about the target data which will not be available when the final model is used for prediction, causing the preformance to be artificially high.

# %%
# converting datetime columns to data type datetime
df['start MTU (UTC)'] = pd.to_datetime(df['start MTU (UTC)'])
df['end MTU (UTC)'] = pd.to_datetime(df['end MTU (UTC)'])

# %% [markdown]
# ## Exploring feature correlation:

# %% [markdown]
# ### Correlation investigation by zone:
#
# **Feature correlation for zone no1**

# %%
# correlation matrix for zone NO1

# creating a dataset containing only columns relating to zone NO1
no1_column_names = [col_name for col_name in df.columns if 'NO1' in col_name]
no1_columns = df.loc[:, no1_column_names]

# calculating correlation
no1_correlation = no1_columns.corr()
# plotting correlation
no1_correlation.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_d025c_row0_col0, #T_d025c_row1_col1, #T_d025c_row2_col2, #T_d025c_row3_col3, #T_d025c_row4_col4, #T_d025c_row5_col5, #T_d025c_row6_col6, #T_d025c_row7_col7, #T_d025c_row8_col8, #T_d025c_row9_col9, #T_d025c_row10_col10, #T_d025c_row11_col11, #T_d025c_row12_col12, #T_d025c_row13_col13, #T_d025c_row14_col14, #T_d025c_row15_col15, #T_d025c_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d025c_row0_col1, #T_d025c_row1_col0, #T_d025c_row2_col12, #T_d025c_row12_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_d025c_row0_col2, #T_d025c_row2_col0, #T_d025c_row4_col9, #T_d025c_row9_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d025c_row0_col3, #T_d025c_row3_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_d025c_row0_col4, #T_d025c_row4_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d025c_row0_col5, #T_d025c_row5_col0, #T_d025c_row5_col6, #T_d025c_row6_col5, #T_d025c_row7_col16, #T_d025c_row16_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_d025c_row0_col6, #T_d025c_row6_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_d025c_row0_col7, #T_d025c_row7_col0, #T_d025c_row7_col9, #T_d025c_row9_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_d025c_row0_col8, #T_d025c_row1_col3, #T_d025c_row1_col13, #T_d025c_row2_col14, #T_d025c_row3_col1, #T_d025c_row8_col0, #T_d025c_row13_col1, #T_d025c_row14_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_d025c_row0_col9, #T_d025c_row9_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_d025c_row0_col10, #T_d025c_row10_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_d025c_row0_col11, #T_d025c_row11_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_d025c_row0_col12, #T_d025c_row0_col13, #T_d025c_row6_col12, #T_d025c_row12_col0, #T_d025c_row12_col6, #T_d025c_row13_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_d025c_row0_col14, #T_d025c_row6_col10, #T_d025c_row10_col6, #T_d025c_row14_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_d025c_row0_col15, #T_d025c_row15_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d025c_row0_col16, #T_d025c_row1_col10, #T_d025c_row6_col7, #T_d025c_row7_col6, #T_d025c_row10_col1, #T_d025c_row16_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_d025c_row1_col2, #T_d025c_row2_col1 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_d025c_row1_col4, #T_d025c_row4_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_d025c_row1_col5, #T_d025c_row3_col5, #T_d025c_row5_col1, #T_d025c_row5_col3, #T_d025c_row5_col7, #T_d025c_row5_col9, #T_d025c_row5_col14, #T_d025c_row7_col5, #T_d025c_row9_col5, #T_d025c_row14_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T
{
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_d025c_row5_col10, #T_d025c_row6_col14, #T_d025c_row10_col5, #T_d025c_row11_col14, #T_d025c_row14_col6, #T_d025c_row14_col11 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_d025c_row5_col11, #T_d025c_row5_col12, #T_d025c_row5_col13, #T_d025c_row11_col5, #T_d025c_row12_col5, #T_d025c_row13_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_d025c_row5_col15, #T_d025c_row15_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_d025c_row5_col16, #T_d025c_row16_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_d025c_row6_col8, #T_d025c_row8_col6, #T_d025c_row13_col16, #T_d025c_row16_col13 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_d025c_row6_col9, #T_d025c_row8_col13, #T_d025c_row9_col6, #T_d025c_row13_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_d025c_row6_col11, #T_d025c_row11_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_d025c_row6_col13, #T_d025c_row7_col10, #T_d025c_row10_col7, #T_d025c_row13_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_d025c_row6_col15, #T_d025c_row15_col6 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_d025c_row7_col1

# %% [markdown]
# <span style="background-color: #FFFF00">TODO: coment on the correlationt</span>

# %% [markdown]
# **Feature correlation for zone NO2**

# %%
# correlation matrix for zone NO2

# creating a dataset containing only columns relating to zone NO1
no2_column_names = [col_name for col_name in df.columns if 'NO2' in col_name]
no2_columns = df.loc[:, no2_column_names]

# adding day ahead price for zone NO1 (target feature)
no2_columns.insert(0, 'Day-ahead Price [EUR/MWh] BZN|NO1', df['Day-ahead Price [EUR/MWh] BZN|NO1'])

# calculating correlation
no2_correlation = no2_columns.corr()

# plotting correlation
no2_correlation.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_7da6f_row0_col0, #T_7da6f_row1_col1, #T_7da6f_row2_col2, #T_7da6f_row3_col3, #T_7da6f_row4_col4, #T_7da6f_row5_col5, #T_7da6f_row6_col6, #T_7da6f_row7_col7, #T_7da6f_row8_col8, #T_7da6f_row9_col9, #T_7da6f_row10_col10, #T_7da6f_row11_col11, #T_7da6f_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7da6f_row0_col1, #T_7da6f_row1_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_7da6f_row0_col2, #T_7da6f_row0_col4, #T_7da6f_row0_col10, #T_7da6f_row2_col0, #T_7da6f_row4_col0, #T_7da6f_row10_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7da6f_row0_col3, #T_7da6f_row3_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_7da6f_row0_col5, #T_7da6f_row5_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_7da6f_row0_col6, #T_7da6f_row6_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_7da6f_row0_col7, #T_7da6f_row7_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_7da6f_row0_col8, #T_7da6f_row8_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_7da6f_row0_col9, #T_7da6f_row9_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_7da6f_row0_col11, #T_7da6f_row2_col5, #T_7da6f_row5_col2, #T_7da6f_row11_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_7da6f_row0_col12, #T_7da6f_row12_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_7da6f_row1_col2, #T_7da6f_row2_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_7da6f_row1_col3, #T_7da6f_row3_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_7da6f_row1_col4, #T_7da6f_row4_col1, #T_7da6f_row7_col9, #T_7da6f_row9_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_7da6f_row1_col5, #T_7da6f_row5_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7da6f_row1_col6, #T_7da6f_row6_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_7da6f_row1_col7, #T_7da6f_row7_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_7da6f_row1_col8, #T_7da6f_row2_col3, #T_7da6f_row3_col2, #T_7da6f_row5_col11, #T_7da6f_row8_col1, #T_7da6f_row11_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_7da6f_row1_col9, #T_7da6f_row2_col8, #T_7da6f_row8_col2, #T_7da6f_row9_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T
_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <th class="col_heading level0 col1" >Day-ahead Price [EUR/MWh] BZN|NO2</th>
#       <th class="col_heading level0 col2" >Actual Total Load [MW] - BZN|NO2</th>
#       <th class="col_heading level0 col3" >Fossil Gas - BZN|NO2</th>
#       <th class="col_heading level0 col4" >Hydro Pumped Storage Aggregated- BZN|NO2</th>
#       <th class="col_heading level0 col5" >Hydro Run-of-river and poundage - BZN|NO2</th>
#       <th class="col_heading level0 col6" >Hydro Water Reservoir - BZN|NO2</th>
#       <th class="col_heading level0 col7" >Other - BZN|NO2</th>
#       <th class="col_heading level0 col8" >Waste - BZN|NO2</th>
#       <th class="col_heading level0 col9" >Wind Onshore - BZN|NO2</th>
#       <th class="col_heading level0 col10" >CBF BZN|NO2 > BZN|NO1 [MW]</th>
#       <th class="col_heading level0 col11" >CBF BZN|NO1 > BZN|NO2 [MW]</th>
#       <th class="col_heading level0 col12" >Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7da6f_level0_row0" class="row_heading level0 row0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <td id="T_7da6f_row0

# %% [markdown]
# <span style="background-color: #FFFF00">TODO: coment on the correlationt</span>

# %% [markdown]
# **Feature correlation for zone NO3**

# %%
# correlation matrix for zone NO3

# creating a dataset containing only columns relating to zone NO1
no3_column_names = [col_name for col_name in df.columns if 'NO3' in col_name]
no3_columns = df.loc[:, no3_column_names]

# adding day ahead price for zone NO1 (target feature)
no3_columns.insert(0, 'Day-ahead Price [EUR/MWh] BZN|NO1', df['Day-ahead Price [EUR/MWh] BZN|NO1'])

# calculating correlation
no3_correlation = no3_columns.corr()

# plotting correlation
no3_correlation.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_021e6_row0_col0, #T_021e6_row1_col1, #T_021e6_row2_col2, #T_021e6_row3_col3, #T_021e6_row4_col4, #T_021e6_row5_col5, #T_021e6_row6_col6, #T_021e6_row7_col7, #T_021e6_row8_col8, #T_021e6_row9_col9, #T_021e6_row10_col10, #T_021e6_row11_col11, #T_021e6_row12_col12, #T_021e6_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_021e6_row0_col1, #T_021e6_row1_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_021e6_row0_col2, #T_021e6_row2_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_021e6_row0_col3, #T_021e6_row3_col0, #T_021e6_row3_col4, #T_021e6_row4_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_021e6_row0_col4, #T_021e6_row4_col0, #T_021e6_row4_col12, #T_021e6_row12_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_021e6_row0_col5, #T_021e6_row5_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_021e6_row0_col6, #T_021e6_row6_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_021e6_row0_col7, #T_021e6_row7_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_021e6_row0_col8, #T_021e6_row8_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_021e6_row0_col9, #T_021e6_row9_col0, #T_021e6_row9_col13, #T_021e6_row13_col9 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_021e6_row0_col10, #T_021e6_row10_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_021e6_row0_col11, #T_021e6_row11_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_021e6_row0_col12, #T_021e6_row12_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_021e6_row0_col13, #T_021e6_row2_col4, #T_021e6_row4_col2, #T_021e6_row13_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_021e6_row1_col2, #T_021e6_row2_col1, #T_021e6_row2_col6, #T_021e6_row6_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_021e6_row1_col3, #T_021e6_row3_col1, #T_021e6_row4_col7, #T_021e6_row7_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_021e6_row1_col4, #T_021e6_row4_col1, #T_021e6_row8_col13, #T_021e6_row13_col8 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_021e6_row1_col5, #T_021e6_row5_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T
{
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_021e6_row7_col10, #T_021e6_row10_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_021e6_row7_col11, #T_021e6_row11_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_021e6_row7_col12, #T_021e6_row12_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_021e6_row8_col9, #T_021e6_row9_col8 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_021e6_row8_col11, #T_021e6_row11_col8 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_021e6_row9_col11, #T_021e6_row11_col9 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_021e6_row11_col12, #T_021e6_row12_col11 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_021e6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <th class="col_heading level0 col1" >Day-ahead Price [EUR/MWh] BZN|NO3</th>
#       <th class="col_heading level0 col2" >Actual Total Load [MW] - BZN|NO3</th>
#       <th class="col_heading level0 col3" >Fossil Gas - BZN|NO3</th>
#       <th class="col_heading level0 col4" >Hydro Pumped Storage Aggregated- BZN|NO3</th>
#       <th class="col_heading level0 col5" >Hydro Run-of-river and poundage - BZN|NO3</th>
#       <th class="col_heading level0 col6" >Hydro Water Reservoir - BZN|NO3</th>
#       <th class="col_heading level0 col7" >Other - BZN|NO3</th>
#       <th class="col_heading level0 col8" >Other renewable - BZ

# %% [markdown]
# <span style="background-color: #FFFF00">TODO: coment on the correlationt</span>

# %% [markdown]
# **Feature correlation for zone NO5**

# %%
# correlation matrix for zone NO5

# creating a dataset containing only columns relating to zone NO1
no5_column_names = [col_name for col_name in df.columns if 'NO2' in col_name]
no5_columns = df.loc[:, no5_column_names]

# adding day ahead price for zone NO1 (target feature)
no5_columns.insert(0, 'Day-ahead Price [EUR/MWh] BZN|NO1', df['Day-ahead Price [EUR/MWh] BZN|NO1'])

# calculating correlation
no5_correlation = no5_columns.corr()

# plotting correlation
no5_correlation.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_ee4a1_row0_col0, #T_ee4a1_row1_col1, #T_ee4a1_row2_col2, #T_ee4a1_row3_col3, #T_ee4a1_row4_col4, #T_ee4a1_row5_col5, #T_ee4a1_row6_col6, #T_ee4a1_row7_col7, #T_ee4a1_row8_col8, #T_ee4a1_row9_col9, #T_ee4a1_row10_col10, #T_ee4a1_row11_col11, #T_ee4a1_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ee4a1_row0_col1, #T_ee4a1_row1_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_ee4a1_row0_col2, #T_ee4a1_row0_col4, #T_ee4a1_row0_col10, #T_ee4a1_row2_col0, #T_ee4a1_row4_col0, #T_ee4a1_row10_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ee4a1_row0_col3, #T_ee4a1_row3_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ee4a1_row0_col5, #T_ee4a1_row5_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_ee4a1_row0_col6, #T_ee4a1_row6_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ee4a1_row0_col7, #T_ee4a1_row7_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ee4a1_row0_col8, #T_ee4a1_row8_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ee4a1_row0_col9, #T_ee4a1_row9_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ee4a1_row0_col11, #T_ee4a1_row2_col5, #T_ee4a1_row5_col2, #T_ee4a1_row11_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_ee4a1_row0_col12, #T_ee4a1_row12_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ee4a1_row1_col2, #T_ee4a1_row2_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ee4a1_row1_col3, #T_ee4a1_row3_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ee4a1_row1_col4, #T_ee4a1_row4_col1, #T_ee4a1_row7_col9, #T_ee4a1_row9_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ee4a1_row1_col5, #T_ee4a1_row5_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_ee4a1_row1_col6, #T_ee4a1_row6_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ee4a1_row8_col12, #T_ee4a1_row12_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_ee4a1_row9_col10, #T_ee4a1_row10_col9 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_ee4a1_row9_col11, #T_ee4a1_row11_col9 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ee4a1_row9_col12, #T_ee4a1_row12_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ee4a1_row10_col11, #T_ee4a1_row11_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ee4a1_row11_col12, #T_ee4a1_row12_col11 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ee4a1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <th class="col_heading level0 col1" >Day-ahead Price [EUR/MWh] BZN|NO2</th>
#       <th class="col_heading level0 col2" >Actual Total Load [MW] - BZN|NO2</th>
#       <th class="col_heading level0 col3" >Fossil Gas - BZN|NO2</th>
#       <th class="col_heading level0 col4" >Hydro Pumped Storage Aggregated- BZN|NO2</th>
#       <th class="col_heading level0 col5" >Hydro Run-of-river and poundage - BZN|NO2</th>
#       <th class="col_heading level0 col6" >Hydro Water Reservoir - BZN|NO2</th>
#       <th class="col_heading level0 col7" >Other - BZN|NO2</th>
#       <th class="col_heading level0 col8" >Waste - BZN|NO2</th>
#       <th class="col_heading level0 col9" >Wind Onshore - BZN|NO2</th>
#       <th class="col_heading level0 col10" >CBF BZN|NO2 > BZN|NO1 [MW]</th>
#       <th class="col_heading level0 col11" >CBF BZN|NO1 > BZN|NO2 [MW]</th>
#       <th class="col_heading level0 col12" >Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|NO2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee4a1_level0_row0" class="row_heading level0 row0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <td id="T_ee4a1_row0

# %% [markdown]
# <span style="background-color: #FFFF00">TODO: coment on the correlationt</span>

# %% [markdown]
# **Feature correlation for zone SE3**

# %%
# correlation matrix for zone SE3

# creating a dataset containing only columns relating to zone NO1
se3_column_names = [col_name for col_name in df.columns if 'SE3' in col_name]
se3_columns = df.loc[:, se3_column_names]

# adding day ahead price for zone NO1 (target feature)
se3_columns.insert(0, 'Day-ahead Price [EUR/MWh] BZN|NO1', df['Day-ahead Price [EUR/MWh] BZN|NO1'])

# calculating correlation
se3_correlation = se3_columns.corr()

# plotting correlation
se3_correlation.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_4a60b_row0_col0, #T_4a60b_row1_col1, #T_4a60b_row2_col2, #T_4a60b_row3_col3, #T_4a60b_row4_col4, #T_4a60b_row5_col5, #T_4a60b_row6_col6, #T_4a60b_row7_col7, #T_4a60b_row8_col8, #T_4a60b_row9_col9, #T_4a60b_row10_col10, #T_4a60b_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4a60b_row0_col1, #T_4a60b_row1_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_4a60b_row0_col2, #T_4a60b_row2_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_4a60b_row0_col3, #T_4a60b_row3_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_4a60b_row0_col4, #T_4a60b_row0_col5, #T_4a60b_row4_col0, #T_4a60b_row5_col0 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_4a60b_row0_col6, #T_4a60b_row6_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_4a60b_row0_col7, #T_4a60b_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_4a60b_row0_col8, #T_4a60b_row2_col7, #T_4a60b_row7_col2, #T_4a60b_row8_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_4a60b_row0_col9, #T_4a60b_row2_col4, #T_4a60b_row4_col2, #T_4a60b_row4_col9, #T_4a60b_row9_col0, #T_4a60b_row9_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T
_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <th class="col_heading level0 col1" >Day-ahead Price [EUR/MWh] BZN|SE3</th>
#       <th class="col_heading level0 col2" >Actual Total Load [MW] - BZN|SE3</th>
#       <th class="col_heading level0 col3" >Fossil Gas - BZN|SE3</th>
#       <th class="col_heading level0 col4" >Hydro Water Reservoir - BZN|SE3</th>
#       <th class="col_heading level0 col5" >Nuclear - BZN|SE3</th>
#       <th class="col_heading level0 col6" >Other - BZN|SE3</th>
#       <th class="col_heading level0 col7" >Solar - BZN|SE3</th>
#       <th class="col_heading level0 col8" >Wind Onshore - BZN|SE3</th>
#       <th class="col_heading level0 col9" >CBF BZN|SE3 > BZN|NO1 [MW]</th>
#       <th class="col_heading level0 col10" >CBF BZN|NO1 > BZN|SE3 [MW]</th>
#       <th class="col_heading level0 col11" >Stored Energy Value Water Reservoirs and Hydro Storage Plants [MWh] - BZN|SE3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a60b_level0_row0" class="row_heading level0 row0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <td id="T_4a60b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4a60b_row0_col1" class="data row0 col1" >0.771236</td>
#       <td id="T_4a60b_row0_col2" class="data row0 col2" >0.044397</td>
#       <td id="T_4a60b_row0_col3" class="data row0 col3" >0.182520</td>
#       <td id="T_4a60b_row0_col4" class="data row0 col4" >0.676582</td>
#       <td id="T_4a60b_row0_col5" class="data row0 col5" >0.678329</td>
#       <td id="T_4a60b_row0_col6" class="data row0 col6" >0.594685</td>
#       <td id="T_4a60b_row0_col7" class="data row0 col7" >0.334046</td>
#       <td id="T_4a60b_row0_col8" class="data row0 col8" >-0.112480</td>
#       <td id="T_4a60b_row0_col9" class="data row0 col9" >0.191673</td>
#       <td id="T_4a60b_row0_col10" class="data row0 col10" >-0.261462</td>
#       <td id="T_4a60b_row0_col11" class="data row0 col11" >-0.387991</td>
#     </tr>
#     <tr>
#       <th id="T_4a60b_level0_row1" class="row_heading level0 row1" >Day-ahead Price [EUR/MWh] BZN|SE3</th>
#       <td id="T_4a60b_row1_col0" class="data row1 col0" >0.771236</td>
#       <td id="

# %% [markdown]
# The target feature 'day-ahead price' for zone NO1 has  reasonably high correlation with the 'day-ahead price' for zone SE3 as well as energy production by source (specifically 'hydro water reservoir', 'nuclear' and 'other'). This indicates that day ahead prices in the two zones tend to increase and decrease at the same time, and that when prices increase production from the sources 'hydro water reservoir', 'nuclear' and 'other' increase with it.
#
# We see that energy production by source (specifically 'hydro water reservoir', 'nuclear' and 'other') has a reasonably strong correlation with 'day-ahead price' for zone SE3. The other features have significantly lower correlation with the day ahead price in this zone.
# Furthermore, we can see that zone SE3 has a very strong possitive correlation between the features representing energy production by source.
#
# We can also seee that 'Stored Energy Value Water Reservoirs and Hydro Storage Plants' have a strong negative correlation with production by source 'hydro water reservoir', 'nuclear' and 'other', which indicate that the stored water in reservoirs and hydtro storage plants tend to go down when produciton by source 'hydro water reservoir', 'nuclear' and 'other' increases.
#
# lastly, we note that the import and the export between SE3 and NO1 have a reasonably strong negative correlation, which indicate that when import increases, export tends to decrease and vise versa.
#
# the high variation in feature correlation indicates that some features are more important than others, and that the model might gain performance through dimentinality reduction so the training can focus on the most important data instead of noise.

# %% [markdown]
# ### Correlation investigation by feature:
#
# **Feature correlation (Day-ahead Price)**

# %%
# correlation matrix for Day-ahead Price

# creating a dataset containing only Day-ahead Price columns
day_ahead_price_column_names = [col_name for col_name in df.columns if 'Day-ahead Price' in col_name]
day_ahead_price_columns = df.loc[:, day_ahead_price_column_names]

# calculating correlation
day_ahead_price_correlation = day_ahead_price_columns.corr()

# plotting correlation
day_ahead_price_correlation.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_9ca90_row0_col0, #T_9ca90_row0_col3, #T_9ca90_row1_col1, #T_9ca90_row2_col2, #T_9ca90_row3_col0, #T_9ca90_row3_col3, #T_9ca90_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9ca90_row0_col1, #T_9ca90_row1_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_9ca90_row0_col2, #T_9ca90_row2_col0, #T_9ca90_row2_col3, #T_9ca90_row3_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_9ca90_row0_col4, #T_9ca90_row4_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_9ca90_row1_col2, #T_9ca90_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9ca90_row1_col3, #T_9ca90_row3_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_9ca90_row1_col4, #T_9ca90_row4_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_9ca90_row2_col4, #T_9ca90_row4_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_9ca90_row3_col4, #T_9ca90_row4_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# </style>
# <table id="T_9ca90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <th class="col_heading level0 col1" >Day-ahead Price [EUR/MWh] BZN|NO2</th>
#       <th class="col_heading level0 col2" >Day-ahead Price [EUR/MWh] BZN|NO3</th>
#       <th class="col_heading level0 col3" >Day-ahead Price [EUR/MWh] BZN|NO5</th>
#       <th class="col_heading level0 col4" >Day-ahead Price [EUR/MWh] BZN|SE3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ca90_level0_row0" class="row_heading level0 row0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <td id="T_9ca90_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9ca90_row0_col1" class="data row0 col1" >0.972172</td>
#       <td id="T_9ca90_row0_col2" class="data row0 col2" >0.463774</td>
#       <td id="T_9ca90_row0_col3" class="data row0 col3" >0.998956</td>
#       <td id="T_9ca90_row0_col4" class="data row0 col4" >0.771236</td>
#     </tr>
#     <tr>
#       <th id="T_9ca90_level0_row1" class="row_heading level0 row1" >Day-ahead Price [EUR/MWh] BZN|NO2</th>
#       <td id="T_9ca90_row1_col0" class="data row1 col0" >0.972172</td>
#       <td id="T_9ca90_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9ca90_row1_col2" class="data row1 col2" >0.390942</td>
#       <td id="T_9ca90_row1_col3" class="data row1 col3" >0.970923</td>
#       <td id="T_9ca90_row1_col4" class="data row1 col4" >0.743452</td>
#     </tr>
#     <tr>
#       <th id="T_9ca90_level0_row2" class="row_heading level0 row2" >Day-ahead Price [EUR/MWh] BZN|NO3</th>
#       <td id="T_9ca90_row2_col0" class="data row2 col0" >0.463774</td>
#       <td id="T_9ca90_row2_col1" class="data row2 col1" >0.390942</td>
#       <td id="T_9ca90_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9ca90_row2_col3" class="data row2 col3" >0.464462</td>
#       <td id="T_9ca90_row2_col4" class="data row2 col4" >0.560566</td>
#     </tr>
#     <tr>
#       <th id="T_9ca90_level0_row3" class="row_heading level0 row3" >Day-ahead Price [EUR/MWh] BZN|NO5</th>
#       <td id="T_9ca90_row3_col0" class="data row3 col0" >0.998956</td>
#       <td id="T_9ca90_row3_col1" class="data row3 col1" >0.970923</td>
#       <td id="T_9ca90_row3_col2" class="data row3 col2" >0.464462</td>
#       <td id="T_9ca90_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9ca90_row3_col4" class="data row3 col4" >0.768764</td>
#     </tr>
#     <tr>
#       <th id="T_9ca90_level0_row4" class="row_heading level0 row4" >Day-ahead Price [EUR/MWh] BZN|SE3</th>
#       <td id="T_9ca90_row4_col0" class="data row4 col0" >0.771236</td>
#       <td id="T_9ca90_row4_col1" class="data row4 col1" >0.743452</td>
#       <td id="T_9ca90_row4_col2" class="data row4 col2" >0.560566</td>
#       <td id="T_9ca90_row4_col3" class="data row4 col3" >0.768764</td>
#       <td id="T_9ca90_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color: #FFFF00">TODO: coment on the correlationt</span>

# %% [markdown]
# **Feature correlation (Load)**

# %%
# correlation matrix for Load

# creating a dataset containing only Load columns
load_column_names = [col_name for col_name in df.columns if 'Load' in col_name]
load_columns = df.loc[:, load_column_names]

# adding day ahead price for zone NO1 (target feature)
load_columns.insert(0, 'Day-ahead Price [EUR/MWh] BZN|NO1', df['Day-ahead Price [EUR/MWh] BZN|NO1'])


# calculating corelatvion
load_correlation = load_columns.corr()
# plotting correlation
load_correlation.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_66237_row0_col0, #T_66237_row1_col1, #T_66237_row2_col2, #T_66237_row3_col3, #T_66237_row4_col4, #T_66237_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_66237_row0_col1, #T_66237_row1_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_66237_row0_col2, #T_66237_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_66237_row0_col3, #T_66237_row3_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_66237_row0_col4, #T_66237_row4_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_66237_row0_col5, #T_66237_row5_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_66237_row1_col2, #T_66237_row2_col1 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_66237_row1_col3, #T_66237_row3_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_66237_row1_col4, #T_66237_row4_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_66237_row1_col5, #T_66237_row5_col1 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_66237_row2_col3, #T_66237_row3_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_66237_row2_col4, #T_66237_row4_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_66237_row2_col5, #T_66237_row5_col2 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_66237_row3_col4, #T_66237_row4_col3 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_66237_row3_col5, #T_66237_row5_col3 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_66237_row4_col5, #T_66237_row5_col4 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_66237_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <th class="col_heading level0 col1" >Actual Total Load [MW] - BZN|NO1</th>
#       <th class="col_heading level0 col2" >Actual Total Load [MW] - BZN|NO2</th>
#       <th class="col_heading level0 col3" >Actual Total Load [MW] - BZN|NO3</th>
#       <th class="col_heading level0 col4" >Actual Total Load [MW] - BZN|NO5</th>
#       <th class="col_heading level0 col5" >Actual Total Load [MW] - BZN|SE3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66237_level0_row0" class="row_heading level0 row0" >Day-ahead Price [EUR/MWh] BZN|NO1</th>
#       <td id="T_66237_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_66237_row0_col1" class="data row0 col1" >-0.055997</td>
#       <td id="T_66237_row0_col2" class="data row0 col2" >-0.087013</td>
#       <td id="T_66237_row0_col3" class="data row0 col3" >0.108040</td>
#       <td id="T_66237_row0_col4" class="data row0 col4" >-0.005517</td>
#       <td id="T_66237_row0_col5" class="data row0 col5" >0.044397</td>
#     </tr>
#     <tr>
#       <th id="T_66237_level0_row1" class="row_heading level0 row1" >Actual Total Load [MW] - BZN|NO1</th>
#       <td id="T_66237_row1_col0" class="data row1 col0" >-0.055997</td>
#       <td id="T_66237_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_66237_row1_col2" class="data row1 col2" >0.962048</td>
#       <td id="T_66237_row1_col3" class="data row1 col3" >0.919751</td>
#       <td id="T_66237_row1_col4" class="data row1 col4" >0.929423</td>
#       <td id="T_66237_row1_col5" class="data row1 col5" >0.954985</td>
#     </tr>
#     <tr>
#       <th id="T_66237_level0_row2" class="row_heading level0 row2" >Actual Total Load [MW] - BZN|NO2</th>
#       <td id="T_66237_row2_col0" class="data row2 col0" >-0.087013</td>
#       <td id="T_66237_row2_col1" class="data row2 col1" >0.962048</td>
#       <td id="T_66237_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_66237_row2_col3" class="data row2 col3" >0.905696</td>
#       <td id="T_66237_row2_col4" class="data row2 col4" >0.927698</td>
#       <td id="T_66237_row2_col5" class="data row2 col5" >0.945594</td>
#     </tr>
#     <tr>
#       <th id="T_66237_level0_row3" class="row_heading level0 row3" >Actual Total Load [MW] - BZN|NO3</th>
#       <td id="T_66237_row3_col0" class="data row3 col0" >0.108040</td>
#       <td id="T_66237_row3_col1" class="data row3 col1" >0.919751</td>
#       <td id="T_66237_row3_col2" class="data row3 col2" >0.905696</td>
#       <td id="T_66237_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_66237_row3_col4" class="data row3 col4" >0.894607</td>
#       <td id="T_66237_row3_col5" class="data row3 col5" >0.914181</td>
#     </tr>
#     <tr>
#       <th id="T_66237_level0_row4" class="row_heading level0 row4" >Actual Total Load [MW] - BZN|NO5</th>
#       <td id="T_66237_row4_col0" class="data row4 col0" >-0.005517</td>
#       <td id="T_66237_row4_col1" class="data row4 col1" >0.929423</td>
#       <td id="T_66237_row4_col2" class="data row4 col2" >0.927698</td>
#       <td id="T_66237_row4_col3" class="data row4 col3" >0.894607</td>
#       <td id="T_66237_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_66237_row4_col5" class="data row4 col5" >0.908984</td>
#     </tr>
#     <tr>
#       <th id="T_66237_level0_row5" class="row_heading level0 row5" >Actual Total Load [MW] - BZN|SE3</th>
#       <td id="T_66237_row5_col0" class="data row5 col0" >0.044397</td>
#       <td id="T_66237_row5_col1" class="data row5 col1" >0.954985</td>
#       <td id="T_66237_row5_col2" class="data row5 col2" >0.945594</td>
#       <td id="T_66237_row5_col3" class="data row5 col3" >0.914181</td>
#       <td id="T_66237_row5_col4" class="data row5 col4" >0.908984</td>
#       <td id="T_66237_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color: #FFFF00">TODO: coment on the correlationt</span>

# %% [markdown]
# <span style="background-color: #FFFF00">!TODO: analyse correlation for remaining feature categories</span>

# %% [markdown]
# ### plotting feature trends
#
# #### Plotting day-ahead price for each zone:

# %%
# creating a dataset containing only datetime and day-ahead price for the different zones
price_column_names = [col_name for col_name in df.columns if 'Day-ahead Price' in col_name]

price_columns = df.loc[:, price_column_names]
price_columns.insert(0, 'start MTU (UTC)', df['start MTU (UTC)'])

price_columns.plot(subplots=True, x='start MTU (UTC)', figsize=(20, 20))

# %% [markdown]
# We can see that the price increases  over time, and that there is a significant shift over the period from 2021 to 2022, and a smaller shift over the period from 2020 to 2021. We can also see that the prive volatility increases over time. The shifts in volatility seem to somewhat align with the shifts to higher prices.
#
# This large shift to higher prices and higher volatility of prices might impeed the algorithms ability to train a model on the data with a high performance in it's price prediction. It might therefore be of value to train one model on the entire dataset and one model on the last year (after the price shift), and compare their performance to see if the performance is increased.

# %% [markdown]
# #### Plotting the load for each zone

# %%
price_column_names = [col_name for col_name in df.columns if 'Load' in col_name]

# creating a dataset containing only datetime and load for the different zones
price_columns = df.loc[:, price_column_names]
price_columns.insert(0, 'start MTU (UTC)', df['start MTU (UTC)'])

price_columns.plot(subplots=True, x='start MTU (UTC)', figsize=(20, 20))
# Out:
# array([<AxesSubplot:xlabel='start MTU (UTC)'>,
#        <AxesSubplot:xlabel='start MTU (UTC)'>,
#        <AxesSubplot:xlabel='start MTU (UTC)'>,
#        <AxesSubplot:xlabel='start MTU (UTC)'>,
#        <AxesSubplot:xlabel='start MTU (UTC)'>], dtype=object)

# %% [markdown]
# <span style="background-color: #FFFF00">TODO: coment on the graph</span>

# %% [markdown]
# ## Handling missing values

# %%
# printing out summary of missing values in the dataset:
df.isna().sum()

# %% [markdown]
# We can now see which features are missing values, and how many values are missing from each feature. We will handle the missing values feature by feature starting with 'Actual Total Load [MW]'
#
# ### Handling missing values for load columns
# We can start by checking which rows are missing values for load features.

# %%
# creating a list of load column names
load_column_names = [col_name for col_name in df.columns if 'Actual Total Load' in col_name]

# creating a new dataframe of load columns and start datetime
load_columns = df.loc[:, load_column_names]
load_columns.insert(0, 'start MTU (UTC)', df['start MTU (UTC)'])

# checking which rows are missing values for any of the 'Actual Total Load' columns
load_columns[load_columns[load_column_names].isnull().any(1)]
# Out:
#           start MTU (UTC)  Actual Total Load [MW] - BZN|NO1  \
# 16057 2021-10-31 01:00:00                               NaN
#
#        Actual Total Load [MW] - BZN|NO2  Actual Total Load [MW] - BZN|NO3  \
# 16057                               NaN                               NaN
#
#        Actual Total Load [MW] - BZN|NO5  Actual Total Load [MW] - BZN|SE3
# 16057                               NaN                              7786

# %% [markdown]
# It seems like none of the Norwegian bidding zones have recorded data for the time interval 31.10.2021 01:00 - 31.10.2021 02:00.
#
# Since it is a dingle row with a missing vlaue, we can simply impute the missing value through interpolation which uses the neighbouring values to generate an the missing intermediary value. We choose to use spline interpolation which estimates the missing values while focusing on minimizing the curvature  of the value graph.

# %%
# performing splilne inerpolation to fill missing values in load columns
for col in load_column_names:
    df[col] = df[col].interpolate(option='spline')

# checking if all the missing values in load columns have been filled:
df.loc[:, load_column_names].isna().sum()
# Out:
# Actual Total Load [MW] - BZN|NO1    0
# Actual Total Load [MW] - BZN|NO2    0
# Actual Total Load [MW] - BZN|NO3    0
# Actual Total Load [MW] - BZN|NO5    0
# Actual Total Load [MW] - BZN|SE3    0
# dtype: int64

# %% [markdown]
# We can see the the 'load' columns no longer conntains any missing values.
#
# ### Handling missing values for Hydro Run-of-river and poundage columns

# %%
# creating a list of Hydro Run-of-river and poundage  column names
hydro_run_of_column_names = [col_name for col_name in df.columns if 'Hydro Run-of-river and poundage' in col_name]

# creating a new dataframe of hydro run of river and pondaage columns and start datetime
hydro_run_of_columns = df.loc[:, hydro_run_of_column_names]
hydro_run_of_columns.insert(0, 'start MTU (UTC)', df['start MTU (UTC)'])

# checking which rows are missing values for any of the 'Hydro Run-of-river and poundage' columns
hydro_run_of_columns[hydro_run_of_columns[hydro_run_of_column_names].isnull().any(1)]

# %% [markdown]
# We can se that the missing values for hydro run of span for a continious interval of 5 hours. Because there are consecutive datapoints missing, we cannot impute the missing values by generating a single and replace every missing value with that value. The reason for this is that these summary statistics do not generate values which accurately reflect the distribution of the underlying data, and can introduce undue bias into the dataset. We therefore opt to use interpolation which generates fill values based on the neighbouring values. To pick an appropriate intorerpolation type we check the graph for the data, and see if the datapoints are more linear in nature (straig lines) or if they seem polynomeal (have a curve):

# %%
# plotting hydro run of river and porage columns
hydro_run_of_columns.drop(['start MTU (UTC)'], axis=1).plot(subplots=True, figsize=(20, 15),  xlabel='hour', ylabel='hydro run of river and porage')

# %% [markdown]
# We can see that the graph is quite jagged, so a linear interpolation is a reasonable option.

# %%
# performing splilne inerpolation to fill missing values in hydro run of columns
for col in hydro_run_of_column_names:
    df[col] = df[col].interpolate(option='linear')
# checking if all the missing values in hydro run of columns have been filled:
df.loc[:, hydro_run_of_column_names].isna().sum()

# %% [markdown]
# We can see the the 'hydro run of' columns no longer conntains any missing values.
#
# ### Handling missing values for fossil gas columns

# %%
# creating a list of fossil gas column names
fossil_gas_column_names = [col_name for col_name in df.columns if 'Fossil Gas' in col_name]

# creating a new dataframe of fossil gas columns and start datetime
fossil_gas_columns = df.loc[:, fossil_gas_column_names]
fossil_gas_columns.insert(0, 'start MTU (UTC)', df['start MTU (UTC)'])

# checking which rows are missing values for any of the fossil gass columns                             
fossil_gas_columns[fossil_gas_columns[fossil_gas_column_names].isnull().any(1)]

# %% [markdown]
# We can se that the first missing values for fossil gas span for a continious interval of 5 hours. The remaining  two missing missing values are interspersed. Since we are dealing with contineous missing values, we opt to use interpolation which generates fill values based on the neighbouring values. To pick an appropriate intorerpolation type we check the graph for the data, and see if the datapoints are more linear in nature (straig lines) or if they seem polynomeal (have a curve):

# %%
# plotting fossil gas columns
fossil_gas_columns.drop(['start MTU (UTC)'], axis=1).plot(subplots=True, figsize=(20, 15),  xlabel='hour', ylabel='fossil gass')

# %% [markdown]
# We can see large periods of no production, and jagged linear shifts in the graphs, so we use linear interploation:

# %%
# performing splilne inerpolation to fill missing values in fossil gas columns
for col in fossil_gas_column_names:
    df[col] = df[col].interpolate(option='linear')
    

# checking if all the missing values in fossil gas columns have been filled:
df.loc[:, fossil_gas_column_names].isna().sum()

# %% [markdown]
# We can see the the 'fossil gas' columns no longer conntains any missing values.
#
# ### Handling missing values for Hydro Water Reservoir columns.
